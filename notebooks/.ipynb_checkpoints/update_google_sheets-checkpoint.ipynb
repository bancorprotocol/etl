# %%
# coding=utf-8
# --------------------------------------------------------------------------------
# Licensed under the Bprotocol Foundation (Bancor) LICENSE. 
# See License.txt in the project root for license information.
# --------------------------------------------------------------------------------
"""
Instructions:

Adding new tables:
* Ensure a spark table exists in databricks with an appropriate table name
* Add the table name to the list of tables in CMD 6 in this notebook.

Adding new columns:
* Update the data dictionary with new column and type in google sheets here: 
    - https://docs.google.com/spreadsheets/d/1ACXfEc2symSVWH-0y7QCMTnADrQInr-czXZrM5GVbJQ/edit#gid=0

Then run... 

Updates require 30+ minutes to complete once started.
"""
# Out:
# '\nInstructions:\n\nAdding new tables:\n* Ensure a spark table exists in databricks with an appropriate table name\n* Add the table name to the list of tables in CMD 6 in this notebook.\n\nAdding new columns:\n* Update the data dictionary with new column and type in google sheets here: \n    - https://docs.google.com/spreadsheets/d/1ACXfEc2symSVWH-0y7QCMTnADrQInr-czXZrM5GVbJQ/edit#gid=0\n\nThen run... \n\nUpdates require 30+ minutes to complete once started.\n'

# %%
from bancor_etl.google_sheets_utils import *

ADDRESS_COLUMNS = [
    # 'contextId', 'pool', 'txhash', 'provider'
]

REPLACE_WITH_NA = ['0E+18', '<NA>']

# Maps the google sheets data dictionary to python/pandas types and fillna values
TYPE_MAP = {
    'decimal': {
        'type': str,
        'fillna': '0.0'
    },
    'integer': {
        'type': int,
        'fillna': 0
    },
    'string': {
        'type': str,
        'fillna': np.nan
    },
    'datetime': {
        'type': 'datetime64[ns]',
        'fillna': np.nan
    },
    'bool': {
        'type': bool,
        'fillna': np.nan
    },
}

LIST_OF_SPARK_TABLES = [
    # Add new table names here (see instructions at top of notebook)

    # NEW TABLES -> implemented on July 5, 2022
    'events_all_tokensdeposited_csv',
    'events_bancornetwork_flashloancompleted_csv',
    'events_bancornetwork_fundsmigrated_csv',
    'events_bancornetwork_networkfeeswithdrawn_csv',
    'events_bancornetwork_pooladded_csv',
    'events_bancornetwork_poolcollectionadded_csv',
    'events_bancornetwork_poolcollectionremoved_csv',
    'events_bancornetwork_poolcreated_csv',
    'events_bancornetwork_poolremoved_csv',
    'events_bancornetwork_tokenstraded_csv',
    'events_bancornetwork_tokenstraded_updated_csv',
    'events_bancorportal_sushiswappositionmigrated_csv',
    'events_bancorportal_uniswapv2positionmigrated_csv',
    'events_bancorv1migration_positionmigrated_csv',
    'events_bntpool_fundingrenounced_csv',
    'events_bntpool_fundingrequested_csv',
    'events_bntpool_fundsburned_csv',
    'events_bntpool_fundswithdrawn_csv',
    'events_bntpool_tokensdeposited_csv',
    'events_bntpool_tokenswithdrawn_csv',
    'events_bntpool_totalliquidityupdated_csv',
    'events_combined_tokenstraded_daily_fees_csv',
    'events_combined_tokenstraded_daily_volume_csv',
    'events_externalprotectionvault_fundsburned_csv',
    'events_externalprotectionvault_fundswithdrawn_csv',
    'events_externalrewardsvault_fundsburned_csv',
    'events_externalrewardsvault_fundswithdrawn_csv',
    'events_mastervault_fundsburned_csv',
    'events_mastervault_fundswithdrawn_csv',
    'events_networksettings_defaultflashloanfeeppmupdated_csv',
    'events_networksettings_flashloanfeeppmupdated_csv',
    'events_networksettings_fundinglimitupdated_csv',
    'events_networksettings_minliquidityfortradingupdated_csv',
    'events_networksettings_tokenaddedtowhitelist_csv',
    'events_networksettings_tokenremovedfromwhitelist_csv',
    'events_networksettings_vortexburnrewardupdated_csv',
    'events_networksettings_withdrawalfeeppmupdated_csv',
    'events_pendingwithdrawals_withdrawalcancelled_csv',
    'events_pendingwithdrawals_withdrawalcompleted_csv',
    'events_pendingwithdrawals_withdrawalcurrentpending_csv',
    'events_pendingwithdrawals_withdrawalinitiated_csv',
    'events_poolcollection_defaulttradingfeeppmupdated_csv',
    'events_poolcollection_depositingenabled_csv',
    'events_poolcollection_tokensdeposited_csv',
    'events_poolcollection_tokenswithdrawn_csv',
    'events_poolcollection_totalliquidityupdated_csv',
    'events_poolcollection_tradingenabled_csv',
    'events_poolcollection_tradingfeeppmupdated_csv',
    'events_poolcollection_tradingliquidityupdated_csv',
    'events_pooldata_historical_latest_csv',
    'events_stakingrewardsclaim_rewardsclaimed_csv',
    'events_stakingrewardsclaim_rewardsstaked_csv',
    'events_standardrewards_programcreated_csv',
    'events_standardrewards_programenabled_csv',
    'events_standardrewards_programterminated_csv',
    'events_standardrewards_providerjoined_csv',
    'events_standardrewards_providerleft_csv',
    'events_standardrewards_rewardsclaimed_csv',
    'events_standardrewards_rewardsstaked_csv',
    'events_v3_daily_bnttradingliquidity_csv',
    'events_v3_historical_deficit_by_tkn_csv',
    'events_v3_historical_deficit_csv',
    'events_v3_historical_spotrates_emarates_csv',
    'events_v3_historical_tradingliquidity_csv'
]

UNUSED_EVENTS = [
    'poolcollection_defaulttradingfeeppmupdated_csv',
    'events_poolcollection_depositingenabled_csv',
    'events_poolcollection_totalliquidityupdated_csv',
    'events_poolcollection_tradingfeeppmupdated_csv',
    'events_poolcollection_tradingliquidityupdated_csv',
    'events_stakingrewardsclaim_rewardsclaimed_csv',
    'events_stakingrewardsclaim_rewardsstaked_csv',
    'events_standardrewards_programcreated_csv',
    'events_standardrewards_programenabled_csv',
    'events_standardrewards_programterminated_csv',
    'events_standardrewards_providerjoined_csv',
    'events_standardrewards_providerleft_csv',
    'events_standardrewards_rewardsclaimed_csv',
    'events_standardrewards_rewardsstaked_csv',
    'events_poolcollection_tradingliquidityupdated_spotrates_csv',
]
# Out:
# 22/07/18 12:46:27 WARN Utils: Your hostname, Michaels-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 10.0.0.147 instead (on interface en0)
# 22/07/18 12:46:27 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/07/18 12:46:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/07/18 12:46:28 WARN MetricsSystem: Using default name SparkStatusTracker for source because neither spark.metrics.namespace nor spark.app.id is set.
# 22/07/18 12:46:28 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from bancor_etl.google_sheets_utils import *
#       3 ADDRESS_COLUMNS = [
#       4     # 'contextId', 'pool', 'txhash', 'provider'
#       5 ]
#       7 REPLACE_WITH_NA = ['0E+18', '<NA>']
#
# File ~/Local/projects/bancor/etl/bancor_etl/google_sheets_utils.py:17, in <module>
#      14 from pyspark.sql import SparkSession
#      15 from sklearn.preprocessing import OrdinalEncoder
# ---> 17 from bancor_etl.constants import *
#      20 # Initialization of dbutils to avoid linting errors during developing in vscode/pycharm/IDE
#      21 def get_dbutils(spark):
#
# File ~/Local/projects/bancor/etl/bancor_etl/constants.py:31, in <module>
#      26 dbutils = get_dbutils(spark)
#      28 # COMMAND ----------
#      29
#      30 # Define parameters
# ---> 31 ETL_USER_NAME = dbutils.secrets.get(scope="ETL", key="ETL_USER_NAME")
#      32 ETL_ROBOT_NAME = dbutils.secrets.get(scope="ETL", key="ETL_ROBOT_NAME")
#      33 ETL_GOOGLE_SHEETS_CREDENTIALS = dbutils.secrets.get(scope="ETL", key="ETL_GOOGLE_SHEETS_CREDENTIALS")
#
# File ~/miniforge3/envs/bancor_research_env/lib/python3.8/site-packages/pyspark/dbutils.py:200, in SecretsHandler.get(self, scope, key)
#     199 def get(self, scope, key):
# --> 200     return self.secrets.get(scope, key)
#
# File ~/miniforge3/envs/bancor_research_env/lib/python3.8/site-packages/py4j/java_gateway.py:1304, in JavaMember.__call__(self, *args)
#    1298 command = proto.CALL_COMMAND_NAME +\
#    1299     self.command_header +\
#    1300     args_command +\
#    1301     proto.END_COMMAND_PART
#    1303 answer = self.gateway_client.send_command(command)
# -> 1304 return_value = get_return_value(
#    1305     answer, self.gateway_client, self.target_id, self.name)
#    1307 for temp_arg in temp_args:
#    1308     temp_arg._detach()
#
# File ~/miniforge3/envs/bancor_research_env/lib/python3.8/site-packages/pyspark/sql/utils.py:117, in capture_sql_exception.<locals>.deco(*a, **kw)
#     115 def deco(*a, **kw):
#     116     try:
# --> 117         return f(*a, **kw)
#     118     except py4j.protocol.Py4JJavaError as e:
#     119         converted = convert_exception(e.java_exception)
#
# File ~/miniforge3/envs/bancor_research_env/lib/python3.8/site-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o29.get.
# : java.lang.SecurityException: To access secrets using Databricks Connect, please contact support to enable this feature on your workspace.
# 	at com.databricks.service.SecretUtilsImpl$.getBytes(DBUtils.scala:240)
# 	at com.databricks.service.SecretUtilsImpl$.get(DBUtils.scala:222)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:195)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:115)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: org.apache.http.client.HttpResponseException: status code: 400, reason phrase: {"error_code":"BAD_REQUEST","message":"This operation is not allowed outside databricks notebooks."}
# 	at com.databricks.service.DBAPIClient.getContent(DBAPIClient.scala:118)
# 	at com.databricks.service.DBAPIClient.jsonGetContent(DBAPIClient.scala:131)
# 	at com.databricks.service.SecretUtilsImpl$.getBytes(DBUtils.scala:236)
# 	... 13 more

# %% [markdown]
# ## Functions

# %%
data_dictionary = get_data_dictionary()
data_dictionary

# %%
ALL_COLUMNS = list(data_dictionary['Column'].values)
NUM_UNIQUE_COLUMNS = len(ALL_COLUMNS)
GOOGLE_SHEETS_MAX_ROWS = int(round(GOOGLE_SHEETS_MAX_CELLS / NUM_UNIQUE_COLUMNS, 0))

for col in ALL_COLUMNS:
    col_type = data_dictionary[data_dictionary['Column'] == col]['Type'].values[0]
    DEFAULT_VALUE_MAP[col] = TYPE_MAP[col_type]['fillna']

DEFAULT_VALUE_MAP
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: {&#39;actualTotalFees_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;actualTotalFees_real_usd&#39;: &#39;0.0&#39;,
#  &#39;amount_real&#39;: &#39;0.0&#39;,
#  &#39;availableAmount_real&#39;: &#39;0.0&#39;,
#  &#39;baseTokenAmount_real&#39;: &#39;0.0&#39;,
#  &#39;blocknumber&#39;: 0,
#  &#39;bntAmount_real&#39;: &#39;0.0&#39;,
#  &#39;bntAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;bntAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;bntFeeAmount_real&#39;: &#39;0.0&#39;,
#  &#39;bntFeeAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;bntFeeAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;bntFundingAmount_real&#39;: &#39;0.0&#39;,
#  &#39;bntFundingLimit_real&#39;: &#39;0.0&#39;,
#  &#39;bntprice&#39;: &#39;0.0&#39;,
#  &#39;bntRemainingFunding_real&#39;: &#39;0.0&#39;,
#  &#39;bntTradingLiquidity_real&#39;: &#39;0.0&#39;,
#  &#39;bntTradingLiquidity_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;bntTradingLiquidity_real_usd&#39;: &#39;0.0&#39;,
#  &#39;caller&#39;: nan,
#  &#39;contextId&#39;: nan,
#  &#39;decimals&#39;: 0,
#  &#39;depositingEnabled&#39;: nan,
#  &#39;emaBlockNumber&#39;: 0,
#  &#39;emaCompressedDenominator&#39;: &#39;0.0&#39;,
#  &#39;emaCompressedNumerator&#39;: &#39;0.0&#39;,
#  &#39;emaDeviation&#39;: &#39;0.0&#39;,
#  &#39;emaInvCompressedDenominator&#39;: &#39;0.0&#39;,
#  &#39;emaInvCompressedNumerator&#39;: &#39;0.0&#39;,
#  &#39;emaInvDeviation&#39;: &#39;0.0&#39;,
#  &#39;emaInvRate&#39;: &#39;0.0&#39;,
#  &#39;emaRate&#39;: &#39;0.0&#39;,
#  &#39;emaRate_usd&#39;: &#39;0.0&#39;,
#  &#39;endTime&#39;: 0,
#  &#39;event_name&#39;: nan,
#  &#39;externalProtectionBaseTokenAmount_real&#39;: &#39;0.0&#39;,
#  &#39;externalProtectionVaultTknBalance_real&#39;: &#39;0.0&#39;,
#  &#39;externalProtectionVaultTknBalance_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;externalProtectionVaultTknBalance_real_usd&#39;: &#39;0.0&#39;,
#  &#39;liquidity_real&#39;: &#39;0.0&#39;,
#  &#39;masterVaultTknBalance_real&#39;: &#39;0.0&#39;,
#  &#39;masterVaultTknBalance_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;masterVaultTknBalance_real_usd&#39;: &#39;0.0&#39;,
#  &#39;newBurnRewardMaxAmount_real&#39;: &#39;0.0&#39;,
#  &#39;newBurnRewardPPM&#39;: 0,
#  &#39;newFeePPM&#39;: 0,
#  &#39;newLimit_real&#39;: &#39;0.0&#39;,
#  &#39;newLiquidity_real&#39;: &#39;0.0&#39;,
#  &#39;newStatus&#39;: nan,
#  &#39;originalAmount_real&#39;: &#39;0.0&#39;,
#  &#39;pool&#39;: nan,
#  &#39;poolCollection&#39;: nan,
#  &#39;poolDecimals&#39;: 0,
#  &#39;poolSymbol&#39;: nan,
#  &#39;poolTokenAmount_real&#39;: &#39;0.0&#39;,
#  &#39;poolTokenSupply_real&#39;: &#39;0.0&#39;,
#  &#39;poolType&#39;: 0,
#  &#39;prevBurnRewardMaxAmount_real&#39;: &#39;0.0&#39;,
#  &#39;prevBurnRewardPPM&#39;: 0,
#  &#39;prevFeePPM&#39;: 0,
#  &#39;prevLimit_real&#39;: &#39;0.0&#39;,
#  &#39;prevLiquidity_real&#39;: &#39;0.0&#39;,
#  &#39;prevStake&#39;: &#39;0.0&#39;,
#  &#39;programId&#39;: 0,
#  &#39;provider&#39;: nan,
#  &#39;reason&#39;: 0,
#  &#39;remainingRewards_real&#39;: &#39;0.0&#39;,
#  &#39;remainingStake_real&#39;: &#39;0.0&#39;,
#  &#39;requestId&#39;: 0,
#  &#39;reserveTokenAmount_real&#39;: &#39;0.0&#39;,
#  &#39;reserveTokenAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;reserveTokenAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;rewardsDecimals&#39;: 0,
#  &#39;rewardsSymbol&#39;: nan,
#  &#39;rewardsToken&#39;: nan,
#  &#39;sourceAmount_real&#39;: &#39;0.0&#39;,
#  &#39;sourceAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;sourceAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;sourceDecimals&#39;: 0,
#  &#39;sourceSpotRate_bnt&#39;: &#39;0.0&#39;,
#  &#39;sourceSymbol&#39;: nan,
#  &#39;sourceToken&#39;: nan,
#  &#39;spotRate&#39;: &#39;0.0&#39;,
#  &#39;spotRate_usd&#39;: &#39;0.0&#39;,
#  &#39;stakedBalance_real&#39;: &#39;0.0&#39;,
#  &#39;stakedBalance_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;stakedBalance_real_usd&#39;: &#39;0.0&#39;,
#  &#39;startTime&#39;: 0,
#  &#39;status&#39;: nan,
#  &#39;surplus_bnt&#39;: &#39;0.0&#39;,
#  &#39;surplus_perc&#39;: &#39;0.0&#39;,
#  &#39;surplus_tkn&#39;: &#39;0.0&#39;,
#  &#39;surplus_usd&#39;: &#39;0.0&#39;,
#  &#39;target&#39;: nan,
#  &#39;targetAmount_real&#39;: &#39;0.0&#39;,
#  &#39;targetAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;targetAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;targetDecimals&#39;: 0,
#  &#39;targetFeeAmount_real&#39;: &#39;0.0&#39;,
#  &#39;targetFeeAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;targetFeeAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;targetSpotRate_bnt&#39;: &#39;0.0&#39;,
#  &#39;targetSymbol&#39;: nan,
#  &#39;targetToken&#39;: nan,
#  &#39;time&#39;: nan,
#  &#39;timeElapsed&#39;: 0,
#  &#39;timestamp&#39;: 0,
#  &#39;tknTradingLiquidity_real&#39;: &#39;0.0&#39;,
#  &#39;tknTradingLiquidity_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;tknTradingLiquidity_real_usd&#39;: &#39;0.0&#39;,
#  &#39;token&#39;: nan,
#  &#39;tokenAmount_real&#39;: &#39;0.0&#39;,
#  &#39;tokenDecimals&#39;: 0,
#  &#39;tokenSymbol&#39;: nan,
#  &#39;totalRewards_real&#39;: &#39;0.0&#39;,
#  &#39;trader&#39;: nan,
#  &#39;tradingEnabled&#39;: nan,
#  &#39;tradingFee&#39;: &#39;0.0&#39;,
#  &#39;tradingFeePPM&#39;: 0,
#  &#39;txhash&#39;: nan,
#  &#39;v2_actualTotalFees_real_usd&#39;: &#39;0.0&#39;,
#  &#39;v2_targetFeeAmount_real&#39;: &#39;0.0&#39;,
#  &#39;v2_targetFeeAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;v2_targetFeeAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;v2_totalVolume_real&#39;: &#39;0.0&#39;,
#  &#39;v2_totalVolume_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;v2_totalVolume_real_usd&#39;: &#39;0.0&#39;,
#  &#39;v3_actualTotalFees_real_usd&#39;: &#39;0.0&#39;,
#  &#39;v3_surplus_bnt&#39;: &#39;0.0&#39;,
#  &#39;v3_surplus_usd&#39;: &#39;0.0&#39;,
#  &#39;v3_targetFeeAmount_real&#39;: &#39;0.0&#39;,
#  &#39;v3_targetFeeAmount_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;v3_targetFeeAmount_real_usd&#39;: &#39;0.0&#39;,
#  &#39;v3_totalVolume_real&#39;: &#39;0.0&#39;,
#  &#39;v3_totalVolume_real_bnt&#39;: &#39;0.0&#39;,
#  &#39;v3_totalVolume_real_usd&#39;: &#39;0.0&#39;,
#  &#39;vbntAmount_real&#39;: &#39;0.0&#39;,
#  &#39;withdrawalFeeAmount_real&#39;: &#39;0.0&#39;}</div>

# %% [markdown]
# ## Combine Tables

# %%
unique_col_mapping, combined_df = get_event_mapping(
    all_columns=ALL_COLUMNS, 
    default_value_map=DEFAULT_VALUE_MAP
)

# Loops through each table.
for table_name in LIST_OF_SPARK_TABLES:
    
    try:
        # Cleans the google sheets name for clarity.
        clean_table_name = clean_google_sheets_name(table_name)

        # Loads spark tables and converts to pandas
        pdf = get_pandas_df(table_name)
        
        # Adds a new column with the event name based on table name
        pdf = add_event_name_column(pdf, clean_table_name)
        
        # Normalizes unique columns across all tables
        pdf = add_missing_columns(pdf, unique_col_mapping, ALL_COLUMNS)

        # Combine the dataframes
        combined_df = concat_dataframes(pdf, combined_df)
        
    except:
        
        print(f'table not found {table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [tokenAmount, poolTokenAmount, vbntAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [amount, availableAmount, originalAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [sourceAmount, targetAmount, bntAmount, targetFeeAmount, bntFeeAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [bntAmount, poolTokenAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [bntAmount, poolTokenAmount, vbntAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [bntAmount, poolTokenAmount, vbntAmount, withdrawalFeeAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [liquidity, stakedBalance, poolTokenSupply] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [amount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [prevLimit, newLimit] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [newLiquidity] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [newBurnRewardMaxAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [poolTokenAmount, reserveTokenAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [poolTokenAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [poolTokenAmount, externalProtectionBaseTokenAmount, bntAmount, withdrawalFeeAmount, baseTokenAmount] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [prevLiquidity, newLiquidity] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [bntTradingLiquidity, tknTradingLiquidity, masterVaultTknBalance, stakedBalance, emaCompressedNumerator, emaCompressedDenominator, emaInvCompressedNumerator, emaInvCompressedDenominator, bntFundingLimit, bntRemainingFunding, bntFundingAmount, externalProtectionVaultTknBalance] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [totalRewards] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [remainingRewards] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [poolTokenAmount, prevStake] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# /databricks/spark/python/pyspark/sql/pandas/utils.py:79: UserWarning: The conversion of DecimalType columns is inefficient and may take a long time. Column names: [poolTokenAmount, remainingStake] If those columns are not necessary, you may consider dropping them or converting to primitive types before the conversion.
#   warnings.warn(
# &lt;command-1998735070835126&gt;:180: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   pdf[col] = [default_value for _ in range(len(pdf))]
# </div>

# %% [markdown]
# ## Handle Types & Missing Values

# %%
combined_df['bntprice'] = combined_df['bntprice'].replace('0E+18','0.0')
combined_df['emaRate'] = combined_df['emaRate'].replace('0E+18','0.0')

combined_df['bntprice'] = combined_df['bntprice'].replace('<NA>','0.0')
combined_df['emaRate'] = combined_df['emaRate'].replace('<NA>','0.0')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# fills in any remaining missing values for encoder
combined_df = handle_types_and_missing_values(combined_df, DEFAULT_VALUE_MAP, ALL_COLUMNS, TYPE_MAP)
combined_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>actualTotalFees_real_bnt</th>
#       <th>actualTotalFees_real_usd</th>
#       <th>amount_real</th>
#       <th>availableAmount_real</th>
#       <th>baseTokenAmount_real</th>
#       <th>blocknumber</th>
#       <th>bntAmount_real</th>
#       <th>bntAmount_real_bnt</th>
#       <th>bntAmount_real_usd</th>
#       <th>bntFeeAmount_real</th>
#       <th>bntFeeAmount_real_bnt</th>
#       <th>bntFeeAmount_real_usd</th>
#       <th>bntFundingAmount_real</th>
#       <th>bntFundingLimit_real</th>
#       <th>bntprice</th>
#       <th>bntRemainingFunding_real</th>
#       <th>bntTradingLiquidity_real</th>
#       <th>bntTradingLiquidity_real_bnt</th>
#       <th>bntTradingLiquidity_real_usd</th>
#       <th>caller</th>
#       <th>contextId</th>
#       <th>decimals</th>
#       <th>depositingEnabled</th>
#       <th>emaBlockNumber</th>
#       <th>emaCompressedDenominator</th>
#       <th>emaCompressedNumerator</th>
#       <th>emaDeviation</th>
#       <th>emaInvCompressedDenominator</th>
#       <th>emaInvCompressedNumerator</th>
#       <th>emaInvDeviation</th>
#       <th>emaInvRate</th>
#       <th>emaRate</th>
#       <th>emaRate_usd</th>
#       <th>endTime</th>
#       <th>event_name</th>
#       <th>externalProtectionBaseTokenAmount_real</th>
#       <th>externalProtectionVaultTknBalance_real</th>
#       <th>externalProtectionVaultTknBalance_real_bnt</th>
#       <th>externalProtectionVaultTknBalance_real_usd</th>
#       <th>liquidity_real</th>
#       <th>...</th>
#       <th>targetFeeAmount_real</th>
#       <th>targetFeeAmount_real_bnt</th>
#       <th>targetFeeAmount_real_usd</th>
#       <th>targetSpotRate_bnt</th>
#       <th>targetSymbol</th>
#       <th>targetToken</th>
#       <th>time</th>
#       <th>timeElapsed</th>
#       <th>timestamp</th>
#       <th>tknTradingLiquidity_real</th>
#       <th>tknTradingLiquidity_real_bnt</th>
#       <th>tknTradingLiquidity_real_usd</th>
#       <th>token</th>
#       <th>tokenAmount_real</th>
#       <th>tokenDecimals</th>
#       <th>tokenSymbol</th>
#       <th>totalRewards_real</th>
#       <th>trader</th>
#       <th>tradingEnabled</th>
#       <th>tradingFee</th>
#       <th>tradingFeePPM</th>
#       <th>txhash</th>
#       <th>v2_actualTotalFees_real_usd</th>
#       <th>v2_targetFeeAmount_real</th>
#       <th>v2_targetFeeAmount_real_bnt</th>
#       <th>v2_targetFeeAmount_real_usd</th>
#       <th>v2_totalVolume_real</th>
#       <th>v2_totalVolume_real_bnt</th>
#       <th>v2_totalVolume_real_usd</th>
#       <th>v3_actualTotalFees_real_usd</th>
#       <th>v3_surplus_bnt</th>
#       <th>v3_surplus_usd</th>
#       <th>v3_targetFeeAmount_real</th>
#       <th>v3_targetFeeAmount_real_bnt</th>
#       <th>v3_targetFeeAmount_real_usd</th>
#       <th>v3_totalVolume_real</th>
#       <th>v3_totalVolume_real_bnt</th>
#       <th>v3_totalVolume_real_usd</th>
#       <th>vbntAmount_real</th>
#       <th>withdrawalFeeAmount_real</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>14611842</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>0xeb324feae5bc66f9b4cf78d647e82f1e92a2e9952fb3...</td>
#       <td>0</td>
#       <td>True</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>all_tokensdeposited</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>2022-04-18 22:38:30</td>
#       <td>0</td>
#       <td>1650321510</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0xEeeeeEeeeEeEeeEeEeEeeEEEeeeeEeeeeeeeEEeE</td>
#       <td>0.001</td>
#       <td>18</td>
#       <td>eth</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>True</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0xc513d308eeb2a5553df65413be187e339fd1fef359d9...</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>14611854</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>0xe648ebc068a6a5b8da0ac50adb6ab890a9965df93dac...</td>
#       <td>0</td>
#       <td>True</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>all_tokensdeposited</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>2022-04-18 22:40:44</td>
#       <td>0</td>
#       <td>1650321644</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0xEeeeeEeeeEeEeeEeEeEeeEEEeeeeEeeeeeeeEEeE</td>
#       <td>0.001</td>
#       <td>18</td>
#       <td>eth</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>True</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0x96d0a1d068b5785c985740fb667df3bfa49bfb29e408...</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>14611870</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>0x9b2160d307f7e721e556126e0a74002d841b6ecfa9a1...</td>
#       <td>0</td>
#       <td>True</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>all_tokensdeposited</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>...</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>2022-04-18 22:43:01</td>
#       <td>0</td>
#       <td>1650321781</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0x6B175474E89094C44Da98b954EedeAC495271d0F</td>
#       <td>49886.47341173564</td>
#       <td>18</td>
#       <td>dai</td>
#       <td>0.0</td>
#       <td>nan</td>
#       <td>True</td>
#       <td>0.0</td>
#       <td>0</td>
#       <td>0x8

# %% [markdown]
# ## Logging

# %%
# Log to mlflow for easy download reference
combined_df.to_csv('/dbfs/FileStore/tables/combined_df.csv', index=False)
mlflow.log_artifact('/dbfs/FileStore/tables/combined_df.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# perform encoding if desired
if len(ADDRESS_COLUMNS) > 0:
    combined_df = encode_address_columns(combined_df, ADDRESS_COLUMNS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Split Dataframe into chunks

# %%
combined_df = remove_unused_events(combined_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_size_compatible = False

while not file_size_compatible:
    
    # Splits the pandas dataframe into chunks which conform to the max google sheet size.
    pdf_chunks = split_dataframe(combined_df, TABLEAU_MANAGEABLE_ROWS)
    
    # Store the number of chunks to upload to google sheets
    num_chunks = len(pdf_chunks)
    
    # Recheck if the file size is <= 10MB per tableau requirements
    file_size_compatible = is_file_size_compatible(pdf_chunks)
    
    # Increment size downward by 1000 and try again if not compatible
    if not file_size_compatible:
        TABLEAU_MANAGEABLE_ROWS -= 1000
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# print expected data size for easy reference
num_chunks, len(combined_df), list(combined_df.columns), TABLEAU_MANAGEABLE_ROWS, GOOGLE_SHEETS_MAX_ROWS
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: (22,
#  196534,
#  [&#39;actualTotalFees_real_bnt&#39;,
#   &#39;actualTotalFees_real_usd&#39;,
#   &#39;amount_real&#39;,
#   &#39;availableAmount_real&#39;,
#   &#39;baseTokenAmount_real&#39;,
#   &#39;blocknumber&#39;,
#   &#39;bntAmount_real&#39;,
#   &#39;bntAmount_real_bnt&#39;,
#   &#39;bntAmount_real_usd&#39;,
#   &#39;bntFeeAmount_real&#39;,
#   &#39;bntFeeAmount_real_bnt&#39;,
#   &#39;bntFeeAmount_real_usd&#39;,
#   &#39;bntFundingAmount_real&#39;,
#   &#39;bntFundingLimit_real&#39;,
#   &#39;bntprice&#39;,
#   &#39;bntRemainingFunding_real&#39;,
#   &#39;bntTradingLiquidity_real&#39;,
#   &#39;bntTradingLiquidity_real_bnt&#39;,
#   &#39;bntTradingLiquidity_real_usd&#39;,
#   &#39;caller&#39;,
#   &#39;contextId&#39;,
#   &#39;decimals&#39;,
#   &#39;depositingEnabled&#39;,
#   &#39;emaBlockNumber&#39;,
#   &#39;emaCompressedDenominator&#39;,
#   &#39;emaCompressedNumerator&#39;,
#   &#39;emaDeviation&#39;,
#   &#39;emaInvCompressedDenominator&#39;,
#   &#39;emaInvCompressedNumerator&#39;,
#   &#39;emaInvDeviation&#39;,
#   &#39;emaInvRate&#39;,
#   &#39;emaRate&#39;,
#   &#39;emaRate_usd&#39;,
#   &#39;endTime&#39;,
#   &#39;event_name&#39;,
#   &#39;externalProtectionBaseTokenAmount_real&#39;,
#   &#39;externalProtectionVaultTknBalance_real&#39;,
#   &#39;externalProtectionVaultTknBalance_real_bnt&#39;,
#   &#39;externalProtectionVaultTknBalance_real_usd&#39;,
#   &#39;liquidity_real&#39;,
#   &#39;masterVaultTknBalance_real&#39;,
#   &#39;masterVaultTknBalance_real_bnt&#39;,
#   &#39;masterVaultTknBalance_real_usd&#39;,
#   &#39;newBurnRewardMaxAmount_real&#39;,
#   &#39;newBurnRewardPPM&#39;,
#   &#39;newFeePPM&#39;,
#   &#39;newLimit_real&#39;,
#   &#39;newLiquidity_real&#39;,
#   &#39;newStatus&#39;,
#   &#39;originalAmount_real&#39;,
#   &#39;pool&#39;,
#   &#39;poolCollection&#39;,
#   &#39;poolDecimals&#39;,
#   &#39;poolSymbol&#39;,
#   &#39;poolTokenAmount_real&#39;,
#   &#39;poolTokenSupply_real&#39;,
#   &#39;poolType&#39;,
#   &#39;prevBurnRewardMaxAmount_real&#39;,
#   &#39;prevBurnRewardPPM&#39;,
#   &#39;prevFeePPM&#39;,
#   &#39;prevLimit_real&#39;,
#   &#39;prevLiquidity_real&#39;,
#   &#39;prevStake&#39;,
#   &#39;programId&#39;,
#   &#39;provider&#39;,
#   &#39;reason&#39;,
#   &#39;remainingRewards_real&#39;,
#   &#39;remainingStake_real&#39;,
#   &#39;requestId&#39;,
#   &#39;reserveTokenAmount_real&#39;,
#   &#39;reserveTokenAmount_real_bnt&#39;,
#   &#39;reserveTokenAmount_real_usd&#39;,
#   &#39;rewardsDecimals&#39;,
#   &#39;rewardsSymbol&#39;,
#   &#39;rewardsToken&#39;,
#   &#39;sourceAmount_real&#39;,
#   &#39;sourceAmount_real_bnt&#39;,
#   &#39;sourceAmount_real_usd&#39;,
#   &#39;sourceDecimals&#39;,
#   &#39;sourceSpotRate_bnt&#39;,
#   &#39;sourceSymbol&#39;,
#   &#39;sourceToken&#39;,
#   &#39;spotRate&#39;,
#   &#39;spotRate_usd&#39;,
#   &#39;stakedBalance_real&#39;,
#   &#39;stakedBalance_real_bnt&#39;,
#   &#39;stakedBalance_real_usd&#39;,
#   &#39;startTime&#39;,
#   &#39;status&#39;,
#   &#39;surplus_bnt&#39;,
#   &#39;surplus_perc&#39;,
#   &#39;surplus_tkn&#39;,
#   &#39;surplus_usd&#39;,
#   &#39;target&#39;,
#   &#39;targetAmount_real&#39;,
#   &#39;targetAmount_real_bnt&#39;,
#   &#39;targetAmount_real_usd&#39;,
#   &#39;targetDecimals&#39;,
#   &#39;targetFeeAmount_real&#39;,
#   &#39;targetFeeAmount_real_bnt&#39;,
#   &#39;targetFeeAmount_real_usd&#39;,
#   &#39;targetSpotRate_bnt&#39;,
#   &#39;targetSymbol&#39;,
#   &#39;targetToken&#39;,
#   &#39;time&#39;,
#   &#39;timeElapsed&#39;,
#   &#39;timestamp&#39;,
#   &#39;tknTradingLiquidity_real&#39;,
#   &#39;tknTradingLiquidity_real_bnt&#39;,
#   &#39;tknTradingLiquidity_real_usd&#39;,
#   &#39;token&#39;,
#   &#39;tokenAmount_real&#39;,
#   &#39;tokenDecimals&#39;,
#   &#39;tokenSymbol&#39;,
#   &#39;totalRewards_real&#39;,
#   &#39;trader&#39;,
#   &#39;tradingEnabled&#39;,
#   &#39;tradingFee&#39;,
#   &#39;tradingFeePPM&#39;,
#   &#39;txhash&#39;,
#   &#39;v2_actualTotalFees_real_usd&#39;,
#   &#39;v2_targetFeeAmount_real&#39;,
#   &#39;v2_targetFeeAmount_real_bnt&#39;,
#   &#39;v2_targetFeeAmount_real_usd&#39;,
#   &#39;v2_totalVolume_real&#39;,
#   &#39;v2_totalVolume_real_bnt&#39;,
#   &#39;v2_totalVolume_real_usd&#39;,
#   &#39;v3_actualTotalFees_real_usd&#39;,
#   &#39;v3_surplus_bnt&#39;,
#   &#39;v3_surplus_usd&#39;,
#   &#39;v3_targetFeeAmount_real&#39;,
#   &#39;v3_targetFeeAmount_real_bnt&#39;,
#   &#39;v3_targetFeeAmount_real_usd&#39;,
#   &#39;v3_totalVolume_real&#39;,
#   &#39;v3_totalVolume_real_bnt&#39;,
#   &#39;v3_totalVolume_real_usd&#39;,
#   &#39;vbntAmount_real&#39;,
#   &#39;withdrawalFeeAmount_real&#39;],
#  9000,
#  72464)</div>

# %% [markdown]
# ## Write Google Sheets

# %%
for i in range(num_chunks):
    handle_google_sheets(f'{EVENTS_TABLE}_{i}', f'{EVENTS_TABLE}_{i}', pdf_chunks[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">all_events_0
# Opened spreadsheet with id:all_events_0
# /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# all_events_1
# Opened spreadsheet with id:all_events_1
# all_events_2
# Opened spreadsheet with id:all_events_2
# all_events_3
# Opened spreadsheet with id:all_events_3
# all_events_4
# Opened spreadsheet with id:all_events_4
# all_events_5
# Opened spreadsheet with id:all_events_5
# all_events_6
# Opened spreadsheet with id:all_events_6
# all_events_7
# Opened spreadsheet with id:all_events_7
# all_events_8
# Opened spreadsheet with id:all_events_8
# all_events_9
# Opened spreadsheet with id:all_events_9
# all_events_10
# Opened spreadsheet with id:all_events_10
# all_events_11
# Opened spreadsheet with id:all_events_11
# all_events_12
# Opened spreadsheet with id:all_events_12
# all_events_13
# Opened spreadsheet with id:all_events_13
# all_events_14
# Opened spreadsheet with id:all_events_14
# all_events_15
# Opened spreadsheet with id:all_events_15
# all_events_16
# Opened spreadsheet with id:all_events_16
# all_events_17
# Opened spreadsheet with id:all_events_17
# all_events_18
# Opened spreadsheet with id:all_events_18
# all_events_19
# Opened spreadsheet with id:all_events_19
# all_events_20
# Opened spreadsheet with id:all_events_20
# all_events_21
# Opened spreadsheet with id:all_events_21
# </div>

# %%
delete_unused_google_sheets(num_chunks)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# combined_df[combined_df.event_name=='v3_historical_spotrates_emarates']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from collections import Counter
Counter(combined_df.event_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: Counter({&#39;all_tokensdeposited&#39;: 11736,
#          &#39;bancornetwork_fundsmigrated&#39;: 6892,
#          &#39;bancornetwork_pooladded&#39;: 594,
#          &#39;bancornetwork_poolcollectionadded&#39;: 8,
#          &#39;bancornetwork_poolcollectionremoved&#39;: 7,
#          &#39;bancornetwork_poolcreated&#39;: 144,
#          &#39;bancornetwork_poolremoved&#39;: 447,
#          &#39;bancornetwork_tokenstraded&#39;: 14282,
#          &#39;bancornetwork_tokenstraded_updated&#39;: 14282,
#          &#39;bntpool_fundingrenounced&#39;: 1347,
#          &#39;bntpool_fundingrequested&#39;: 2534,
#          &#39;bntpool_tokensdeposited&#39;: 6370,
#          &#39;bntpool_tokenswithdrawn&#39;: 859,
#          &#39;bntpool_totalliquidityupdated&#39;: 3881,
#          &#39;combined_tokenstraded_daily_fees&#39;: 9002,
#          &#39;combined_tokenstraded_daily_volume&#39;: 11041,
#          &#39;externalprotectionvault_fundswithdrawn&#39;: 15,
#          &#39;mastervault_fundsburned&#39;: 1384,
#          &#39;mastervault_fundswithdrawn&#39;: 15926,
#          &#39;networksettings_defaultflashloanfeeppmupdated&#39;: 1,
#          &#39;networksettings_fundinglimitupdated&#39;: 167,
#          &#39;networksettings_minliquidityfortradingupdated&#39;: 1,
#          &#39;networksettings_tokenaddedtowhitelist&#39;: 147,
#          &#39;networksettings_vortexburnrewardupdated&#39;: 1,
#          &#39;networksettings_withdrawalfeeppmupdated&#39;: 2,
#          &#39;pendingwithdrawals_withdrawalcancelled&#39;: 705,
#          &#39;pendingwithdrawals_withdrawalcompleted&#39;: 2503,
#          &#39;pendingwithdrawals_withdrawalcurrentpending&#39;: 811,
#          &#39;pendingwithdrawals_withdrawalinitiated&#39;: 4019,
#          &#39;poolcollection_defaulttradingfeeppmupdated&#39;: 8,
#          &#39;poolcollection_depositingenabled&#39;: 156,
#          &#39;poolcollection_tokensdeposited&#39;: 5366,
#          &#39;poolcollection_tokenswithdrawn&#39;: 1646,
#          &#39;poolcollection_totalliquidityupdated&#39;: 7011,
#          &#39;poolcollection_tradingenabled&#39;: 217,
#          &#39;poolcollection_tradingfeeppmupdated&#39;: 191,
#          &#39;poolcollection_tradingliquidityupdated&#39;: 50231,
#          &#39;pooldata_historical_latest&#39;: 88,
#          &#39;stakingrewardsclaim_rewardsclaimed&#39;: 1106,
#          &#39;stakingrewardsclaim_rewardsstaked&#39;: 1529,
#          &#39;standardrewards_programcreated&#39;: 8,
#          &#39;standardrewards_programenabled&#39;: 8,
#          &#39;standardrewards_programterminated&#39;: 4,
#          &#39;standardrewards_providerjoined&#39;: 5381,
#          &#39;standardrewards_providerleft&#39;: 2720,
#          &#39;standardrewards_rewardsclaimed&#39;: 791,
#          &#39;standardrewards_rewardsstaked&#39;: 181,
#          &#39;v3_daily_bnttradingliquidity&#39;: 91,
#          &#39;v3_historical_deficit_by_tkn&#39;: 3534,
#          &#39;v3_historical_deficit&#39;: 91,
#          &#39;v3_historical_spotrates_emarates&#39;: 3534,
#          &#39;v3_historical_tradingliquidity&#39;: 3534})</div>
